# %%
import os
import psycopg2
from dotenv import load_dotenv
import requests
import pandas as pd

API_KEY = os.getenv("ALPHA_VANTAGE_API_KEY")
BASE_URL = "https://www.alphavantage.co/query"

params = {
    "function": "TIME_SERIES_DAILY",
    "symbol": "GOOGL",
    "apikey": API_KEY,
    "outputsize": "compact"  
}

response = requests.get(BASE_URL, params=params)
data = response.json()

df = pd.DataFrame.from_dict(
    data["Time Series (Daily)"],
    orient="index"
)

df.index = pd.to_datetime(df.index)
df = df.astype(float)
df.sort_index(inplace=True)
# Out:
#             1. open  2. high   3. low  4. close    5. volume
# 2025-08-27   205.70  208.910  205.650    207.48   23022850.0
# 2025-08-28   207.25  212.220  206.900    211.64   32339307.0
# 2025-08-29   210.51  214.645  210.200    212.91   39728364.0
# 2025-09-02   208.44  211.675  206.195    211.35   47523037.0
# 2025-09-03   226.21  231.310  224.790    230.66  102090277.0
# ...             ...      ...      ...       ...          ...
# 2026-01-13   334.95  340.490  333.620    335.97   33517607.0
# 2026-01-14   335.06  336.520  330.480    335.84   28525571.0
# 2026-01-15   337.65  337.690  330.740    332.78   28442406.0
# 2026-01-16   334.41  334.650  327.700    330.00   40341637.0
# 2026-01-20   320.87  327.730  320.430    322.00   34808916.0
#
# [100 rows x 5 columns]
